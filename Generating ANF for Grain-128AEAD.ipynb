# %%
#!/usr/bin/env python
# coding: utf-8

# In[3]:


from sage.crypto.boolean_function import BooleanFunction
from random import randint
import random
import numpy

R.<s0, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28, s29, s30, s31, s32, s33, s34, s35, s36, s37, s38, s39, s40, s41, s42, s43, s44, s45, s46, s47, s48, s49, s50, s51, s52, s53, s54, s55, s56, s57, s58, s59, s60, s61, s62, s63, s64, s65, s66, s67, s68, s69, s70, s71, s72, s73, s74, s75, s76, s77, s78, s79, s80, s81, s82, s83, s84, s85, s86, s87, s88, s89, s90, s91, s92, s93, s94, s95, s96, s97, s98, s99, s100, s101, s102, s103, s104, s105, s106, s107, s108, s109, s110, s111, s112, s113, s114, s115, s116, s117, s118, s119, s120, s121, s122, s123, s124, s125, s126, s127, b0, b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b11, b12, b13, b14, b15, b16, b17, b18, b19, b20, b21, b22, b23, b24, b25, b26, b27, b28, b29, b30, b31, b32, b33, b34, b35, b36, b37, b38, b39, b40, b41, b42, b43, b44, b45, b46, b47, b48, b49, b50, b51, b52, b53, b54, b55, b56, b57, b58, b59, b60, b61, b62, b63, b64, b65, b66, b67, b68, b69, b70, b71, b72, b73, b74, b75, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, b90, b91, b92, b93, b94, b95, b96, b97, b98, b99, b100, b101, b102, b103, b104, b105, b106, b107, b108, b109, b110, b111, b112, b113, b114, b115, b116, b117, b118, b119, b120, b121, b122, b123, b124, b125, b126, b127, k0, k1, k2, k3, k4, k5, k6, k7, k8, k9, k10, k11, k12, k13, k14, k15, k16, k17, k18, k19, k20, k21, k22, k23, k24, k25, k26, k27, k28, k29, k30, k31, k32, k33, k34, k35, k36, k37, k38, k39, k40, k41, k42, k43, k44, k45, k46, k47, k48, k49, k50, k51, k52, k53, k54, k55, k56, k57, k58, k59, k60, k61, k62, k63, k64, k65, k66, k67, k68, k69, k70, k71, k72, k73, k74, k75, k76, k77, k78, k79, k80, k81, k82, k83, k84, k85, k86, k87, k88, k89, k90, k91, k92, k93, k94, k95, k96, k97, k98, k99, k100, k101, k102, k103, k104, k105, k106, k107, k108, k109, k110, k111, k112, k113, k114, k115, k116, k117, k118, k119, k120, k121, k122, k123, k124, k125, k126, k127> = BooleanPolynomialRing()

R.inject_variables()

S_256 = [R.gens()[u] for u in range(128)] #Original State at S^[256]
S = [R.gens()[u] for u in range(128)] #State at S^[256]
K = [R.gens()[u] for u in range(256,384,1)]
#print(S)
B = [R.gens()[u] for u in range(128,256,1)]
#print (B)

def grain(i,fr,state):
    if fr == 1:
        S[i] = state
    elif fr == 2:
        B[i] = state

    #update function of LFSR and NFSR
    feedback_L = S[0] + S[7] + S[38] + S[70] + S[81] + S[96]
    feedback_N = S[0] + B[0] + B[26] + B[56] + B[91] + B[96] + B[3] * B[67] + B[11] * B[13] + B[17] * B[18] + B[27] * B[59] + B[40] * B[48] + B[61] * B[65] + B[68] * B[84] + B[22] * B[24] * B[25] + B[70] * B[78] * B[82] + B[88] * B[92] * B[93] * B[95]
    #feedback update
    #S[127] = feedback_L
    #B[127] = feedback_N
    
    #State update function
    for j in range(128):
        if j<=126:
            S[j] = S[j+1]
            B[j] = B[j+1]
        else:
            S[127] = feedback_L
            B[127] = feedback_N
    #h function
    h = B[12]*S[8] + S[13]*S[20] + B[95]*S[42] + S[60]*S[79] + B[12]*B[95]*S[94]
    #pre-output function
    z = h + S[93] + B[2]+ B[15] + B[36] + B[45] + B[64] + B[73] + B[89]
    return z

count = 0
eqList = ["eq"]

#State Update
#the maximun is 65
for i in range(51):
    #print (i)
    z = grain(13,1,S[13])
    #print (z)
    
    if i%2 == 0: # Output the even bits of keystreams
        for v in range(128):
            X = diff(z, S_256[v]) #Differentiate with respect certain bit in S
            if X!=0 and X!= 1:                
                poly = str(X)                
                if poly.find("*")<0:
                    print('eq', i,'_','s',v,'=',X,sep='')
                    eqnum = "eq" + str(i) + '_' + "s"+ str(v)
                    count = count + 1
                    eqList.append(eqnum)
        print ('--------------------------------------------------------------------------------------------------------------')
        
print('end')
print (eqList) 


# In[ ]:
# Out:
# Defining s0, s1, s2, s3, s4, s5, s6, s7, s8, s9, s10, s11, s12, s13, s14, s15, s16, s17, s18, s19, s20, s21, s22, s23, s24, s25, s26, s27, s28, s29, s30, s31, s32, s33, s34, s35, s36, s37, s38, s39, s40, s41, s42, s43, s44, s45, s46, s47, s48, s49, s50, s51, s52, s53, s54, s55, s56, s57, s58, s59, s60, s61, s62, s63, s64, s65, s66, s67, s68, s69, s70, s71, s72, s73, s74, s75, s76, s77, s78, s79, s80, s81, s82, s83, s84, s85, s86, s87, s88, s89, s90, s91, s92, s93, s94, s95, s96, s97, s98, s99, s100, s101, s102, s103, s104, s105, s106, s107, s108, s109, s110, s111, s112, s113, s114, s115, s116, s117, s118, s119, s120, s121, s122, s123, s124, s125, s126, s127, b0, b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b11, b12, b13, b14, b15, b16, b17, b18, b19, b20, b21, b22, b23, b24, b25, b26, b27, b28, b29, b30, b31, b32, b33, b34, b35, b36, b37, b38, b39, b40, b41, b42, b43, b44, b45, b46, b47, b48, b49, b50, b51, b52, b53, b54, b55, b56, b57, b58, b59, b60, b61, b62, b63, b64, b65, b66, b67, b68, b69, b70, b71, b72, b73, b74, b75, b76, b77, b78, b79, b80, b81, b82, b83, b84, b85, b86, b87, b88, b89, b90, b91, b92, b93, b94, b95, b96, b97, b98, b99, b100, b101, b102, b103, b104, b105, b106, b107, b108, b109, b110, b111, b112, b113, b114, b115, b116, b117, b118, b119, b120, b121, b122, b123, b124, b125, b126, b127, k0, k1, k2, k3, k4, k5, k6, k7, k8, k9, k10, k11, k12, k13, k14, k15, k16, k17, k18, k19, k20, k21, k22, k23, k24, k25, k26, k27, k28, k29, k30, k31, k32, k33, k34, k35, k36, k37, k38, k39, k40, k41, k42, k43, k44, k45, k46, k47, k48, k49, k50, k51, k52, k53, k54, k55, k56, k57, k58, k59, k60, k61, k62, k63, k64, k65, k66, k67, k68, k69, k70, k71, k72, k73, k74, k75, k76, k77, k78, k79, k80, k81, k82, k83, k84, k85, k86, k87, k88, k89, k90, k91, k92, k93, k94, k95, k96, k97, k98, k99, k100, k101, k102, k103, k104, k105, k106, k107, k108, k109, k110, k111, k112, k113, k114, k115, k116, k117, k118, k119, k120, k121, k122, k123, k124, k125, k126, k127
# eq0_s9=b13
# eq0_s14=s21
# eq0_s21=s14
# eq0_s43=b96
# eq0_s61=s80
# eq0_s80=s61
# --------------------------------------------------------------------------------------------------------------
# eq2_s11=b15
# eq2_s16=s23
# eq2_s23=s16
# eq2_s45=b98
# eq2_s63=s82
# eq2_s82=s63
# --------------------------------------------------------------------------------------------------------------
# eq4_s13=b17
# eq4_s18=s25
# eq4_s25=s18
# eq4_s47=b100
# eq4_s65=s84
# eq4_s84=s65
# --------------------------------------------------------------------------------------------------------------
# eq6_s15=b19
# eq6_s20=s27
# eq6_s27=s20
# eq6_s49=b102
# eq6_s67=s86
# eq6_s86=s67
# --------------------------------------------------------------------------------------------------------------
# eq8_s17=b21
# eq8_s22=s29
# eq8_s29=s22
# eq8_s51=b104
# eq8_s69=s88
# eq8_s88=s69
# --------------------------------------------------------------------------------------------------------------
# eq10_s19=b23
# eq10_s24=s31
# eq10_s31=s24
# eq10_s53=b106
# eq10_s71=s90
# eq10_s90=s71
# --------------------------------------------------------------------------------------------------------------
# eq12_s21=b25
# eq12_s26=s33
# eq12_s33=s26
# eq12_s55=b108
# eq12_s73=s92
# eq12_s92=s73
# --------------------------------------------------------------------------------------------------------------
# eq14_s23=b27
# eq14_s28=s35
# eq14_s35=s28
# eq14_s57=b110
# eq14_s75=s94
# eq14_s94=s75
# --------------------------------------------------------------------------------------------------------------
# eq16_s25=b29
# eq16_s30=s37
# eq16_s37=s30
# eq16_s59=b112
# eq16_s77=s96
# eq16_s96=s77
# --------------------------------------------------------------------------------------------------------------
# eq18_s27=b31
# eq18_s32=s39
# eq18_s39=s32
# eq18_s61=b114
# eq18_s79=s98
# eq18_s98=s79
# --------------------------------------------------------------------------------------------------------------
# eq20_s29=b33
# eq20_s34=s41
# eq20_s41=s34
# eq20_s63=b116
# eq20_s81=s100
# eq20_s100=s81
# --------------------------------------------------------------------------------------------------------------
# eq22_s31=b35
# eq22_s36=s43
# eq22_s43=s36
# eq22_s65=b118
# eq22_s83=s102
# eq22_s102=s83
# --------------------------------------------------------------------------------------------------------------
# eq24_s33=b37
# eq24_s38=s45
# eq24_s45=s38
# eq24_s67=b120
# eq24_s85=s104
# eq24_s104=s85
# --------------------------------------------------------------------------------------------------------------
# eq26_s35=b39
# eq26_s40=s47
# eq26_s47=s40
# eq26_s69=b122
# eq26_s87=s106
# eq26_s106=s87
# --------------------------------------------------------------------------------------------------------------
# eq28_s37=b41
# eq28_s42=s49
# eq28_s49=s42
# eq28_s71=b124
# eq28_s89=s108
# eq28_s108=s89
# --------------------------------------------------------------------------------------------------------------
# eq30_s39=b43
# eq30_s44=s51
# eq30_s51=s44
# eq30_s73=b126
# eq30_s91=s110
# eq30_s110=s91
# --------------------------------------------------------------------------------------------------------------
# eq32_s41=b45
# eq32_s46=s53
# eq32_s53=s46
# eq32_s93=s112
# eq32_s112=s93
# --------------------------------------------------------------------------------------------------------------
# eq34_s43=b47
# eq34_s48=s55
# eq34_s55=s48
# eq34_s95=s114
# eq34_s114=s95
# --------------------------------------------------------------------------------------------------------------
# eq36_s45=b49
# eq36_s50=s57
# eq36_s57=s50
# eq36_s97=s116
# eq36_s116=s97
# --------------------------------------------------------------------------------------------------------------
# eq38_s47=b51
# eq38_s52=s59
# eq38_s59=s52
# eq38_s99=s118
# eq38_s118=s99
# --------------------------------------------------------------------------------------------------------------
# eq40_s49=b53
# eq40_s54=s61
# eq40_s61=s54
# eq40_s101=s120
# eq40_s120=s101
# --------------------------------------------------------------------------------------------------------------
# eq42_s51=b55
# eq42_s56=s63
# eq42_s63=s56
# eq42_s103=s122
# eq42_s122=s103
# --------------------------------------------------------------------------------------------------------------
# eq44_s53=b57
# eq44_s58=s65
# eq44_s65=s58
# eq44_s105=s124
# eq44_s124=s105
# --------------------------------------------------------------------------------------------------------------
# eq46_s55=b59
# eq46_s60=s67
# eq46_s67=s60
# eq46_s107=s126
# eq46_s126=s107
# --------------------------------------------------------------------------------------------------------------
# eq48_s0=s109
# eq48_s7=s109
# eq48_s38=s109
# eq48_s57=b61
# eq48_s62=s69
# eq48_s69=s62
# eq48_s70=s109
# eq48_s81=s109
# eq48_s109=s0 + s38 + s7 + s70 + s81 + s96
# --------------------------------------------------------------------------------------------------------------
# eq50_s2=s111
# eq50_s9=s111
# eq50_s40=s111
# eq50_s59=b63
# eq50_s64=s71
# eq50_s71=s64
# eq50_s72=s111
# eq50_s83=s111
# eq50_s111=s2 + s40 + s72 + s83 + s9 + s98
# --------------------------------------------------------------------------------------------------------------
# end
# ['eq', 'eq0_s9', 'eq0_s14', 'eq0_s21', 'eq0_s43', 'eq0_s61', 'eq0_s80', 'eq2_s11', 'eq2_s16', 'eq2_s23', 'eq2_s45', 'eq2_s63', 'eq2_s82', 'eq4_s13', 'eq4_s18', 'eq4_s25', 'eq4_s47', 'eq4_s65', 'eq4_s84', 'eq6_s15', 'eq6_s20', 'eq6_s27', 'eq6_s49', 'eq6_s67', 'eq6_s86', 'eq8_s17', 'eq8_s22', 'eq8_s29', 'eq8_s51', 'eq8_s69', 'eq8_s88', 'eq10_s19', 'eq10_s24', 'eq10_s31', 'eq10_s53', 'eq10_s71', 'eq10_s90', 'eq12_s21', 'eq12_s26', 'eq12_s33', 'eq12_s55', 'eq12_s73', 'eq12_s92', 'eq14_s23', 'eq14_s28', 'eq14_s35', 'eq14_s57', 'eq14_s75', 'eq14_s94', 'eq16_s25', 'eq16_s30', 'eq16_s37', 'eq16_s59', 'eq16_s77', 'eq16_s96', 'eq18_s27', 'eq18_s32', 'eq18_s39', 'eq18_s61', 'eq18_s79', 'eq18_s98', 'eq20_s29', 'eq20_s34', 'eq20_s41', 'eq20_s63', 'eq20_s81', 'eq20_s100', 'eq22_s31', 'eq22_s36', 'eq22_s43', 'eq22_s65', 'eq22_s83', 'eq22_s102', 'eq24_s33', 'eq24_s38', 'eq24_s45', 'eq24_s67', 'eq24_s85', 'eq24_s104', 'eq26_s35', 'eq26_s40', 'eq26_s47', 'eq26_s69', 'eq26_s87', 'eq26_s106', 'eq28_s37', 'eq28_s42', 'eq28_s49', 'eq28_s71', 'eq28_s89', 'eq28_s108', 'eq30_s39', 'eq30_s44', 'eq30_s51', 'eq30_s73', 'eq30_s91', 'eq30_s110', 'eq32_s41', 'eq32_s46', 'eq32_s53', 'eq32_s93', 'eq32_s112', 'eq34_s43', 'eq34_s48', 'eq34_s55', 'eq34_s95', 'eq34_s114', 'eq36_s45', 'eq36_s50', 'eq36_s57', 'eq36_s97', 'eq36_s116', 'eq38_s47', 'eq38_s52', 'eq38_s59', 'eq38_s99', 'eq38_s118', 'eq40_s49', 'eq40_s54', 'eq40_s61', 'eq40_s101', 'eq40_s120', 'eq42_s51', 'eq42_s56', 'eq42_s63', 'eq42_s103', 'eq42_s122', 'eq44_s53', 'eq44_s58', 'eq44_s65', 'eq44_s105', 'eq44_s124', 'eq46_s55', 'eq46_s60', 'eq46_s67', 'eq46_s107', 'eq46_s126', 'eq48_s0', 'eq48_s7', 'eq48_s38', 'eq48_s57', 'eq48_s62', 'eq48_s69', 'eq48_s70', 'eq48_s81', 'eq48_s109', 'eq50_s2', 'eq50_s9', 'eq50_s40', 'eq50_s59', 'eq50_s64', 'eq50_s71', 'eq50_s72', 'eq50_s83', 'eq50_s111']
